# %% [markdown]
# # Times series : Regression ancak zamana bagli Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('DailyDelhiClimateTrain.csv')

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
px.line(df,x='date',y='meantemp',title='New Delhi Ortalama Sıcaklık')
# Out:
# <div>                            <div id="48615b96-f92d-450a-b2f1-4be305376929" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48615b96-f92d-450a-b2f1-4be305376929")) {                    Plotly.newPlot(                        "48615b96-f92d-450a-b2f1-4be305376929",                        [{"hovertemplate":"date=%{x}<br>meantemp=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-01","2013-01-02","2013-01-03","2013-01-04","2013-01-05","2013-01-06","2013-01-07","2013-01-08","2013-01-09","2013-01-10","2013-01-11","2013-01-12","2013-01-13","2013-01-14","2013-01-15","2013-01-16","2013-01-17","2013-01-18","2013-01-19","2013-01-20","2013-01-
# ...

# %%
df.meantemp.plot()
# Out:
# <Axes: >

# %%
px.line(df,x='date',y='humidity',title='New Delhi Ortalama Nem')
# Out:
# <div>                            <div id="16ebc35f-1fbe-4745-969a-71ead311d509" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16ebc35f-1fbe-4745-969a-71ead311d509")) {                    Plotly.newPlot(                        "16ebc35f-1fbe-4745-969a-71ead311d509",                        [{"hovertemplate":"date=%{x}<br>humidity=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-01","2013-01-02","2013-01-03","2013-01-04","2013-01-05","2013-01-06","2013-01-07","2013-01-08","2013-01-09","2013-01-10","2013-01-11","2013-01-12","2013-01-13","2013-01-14","2013-01-15","2013-01-16","2013-01-17","2013-01-18","2013-01-19","2013-01-20","2013-01-
# ...

# %%
px.line(df,x='date',y='wind_speed',title='New Delhi Ortalama Rüzgar Hızı')
# Out:
# <div>                            <div id="c919b5ed-561a-4bd8-a129-d45259dadcd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c919b5ed-561a-4bd8-a129-d45259dadcd1")) {                    Plotly.newPlot(                        "c919b5ed-561a-4bd8-a129-d45259dadcd1",                        [{"hovertemplate":"date=%{x}<br>wind_speed=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-01","2013-01-02","2013-01-03","2013-01-04","2013-01-05","2013-01-06","2013-01-07","2013-01-08","2013-01-09","2013-01-10","2013-01-11","2013-01-12","2013-01-13","2013-01-14","2013-01-15","2013-01-16","2013-01-17","2013-01-18","2013-01-19","2013-01-20","2013-0
# ...

# %%
px.scatter(df,x='humidity',y='meantemp',size='meantemp',trendline='ols')
# Out:
# <div>                            <div id="3f6252d4-29e0-4055-9255-c89167659e61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f6252d4-29e0-4055-9255-c89167659e61")) {                    Plotly.newPlot(                        "3f6252d4-29e0-4055-9255-c89167659e61",                        [{"hovertemplate":"humidity=%{x}<br>meantemp=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[10.0,7.4,7.166666666666667,8.666666666666666,6.0,7.0,7.0,8.857142857142858,14.0,11.0,15.714285714285714,14.0,15.833333333333334,12.833333333333334,14.714285714285714,13.833333333333334,16.5,13.833333333333334,12.5,11.285714285714286,11.2,9.5,14.0,13.833333333333334,12.25,12.666666666666666,12.857142857142858,14.833333333333334,14.125,14.
# ...

# %%
df['date']=pd.to_datetime(df['date'],format='%Y-%m-%d')

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month

# %%
df.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1

# %%
plt.figure(figsize=(15,10))
sns.lineplot(df,x='month',y='meantemp',hue='year')
# Out:
# <Axes: xlabel='month', ylabel='meantemp'>

# %%
df.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1

# %%
#pip install prophet

# %%
forecast_data=df.rename(columns={'date':'ds','meantemp':'y'})

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
model=Prophet()
model.fit(forecast_data)
forecast=model.make_future_dataframe(periods=365)
predictions=model.predict(forecast)
plot_plotly(model, predictions)
# Out:
# 13:56:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:56:49 - cmdstanpy - INFO - Chain [1] done processing
# ...
